# %% [markdown]
# <font color='red'><b><u> Reviewer Comment. V. 2</u></b></font>
# <div class="alert alert-block alert-danger">
#
# **General feedback:**
#
# Hello!
#
# I'm really glad to tell you that your project looks much better, thank you for corrections! 😃
#
# However, there is one issue left, [check it](#issue5) and correct, please.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. V.1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Hello! I am Larchenko Ksenia and I'm glad to review your project**!
#
#
# You can find my comments in green, yellow and red boxes like these:
# </div>
#
#
# <div class="alert alert-success" >
#
#
# **Success:**  green color shows that everything is done perfectly;
#
# </div>
#
# <div class="alert alert-warning" >
#
#
# **Remark & Recommendation:** yellow color highlights something to pay attention for;
#
# </div>
#
#
#
# <div class="alert alert-danger" >
#
#
# **Needs fixing:**  if the color is red, please rework.
#
# </div>
#
# ____
#
# <div class="alert alert-success" >
#
#
# **Please, don't remove my comments:)**
#
# </div>
#
# <font color='green'><b><u> Reviewer Comment. V.1 </u></b></font>
# <div class="alert alert-block alert-success">
#
# **General feedback :**
#
# Thank you for sending your project. You've done a really good job on it!
#
#
#
# What impressed me?
#
#
# * Different important methods for working with data were used **(corr, groupby and others)**! It is really great that you can apply these methods on practice, keep it up!
# * I like  conclusions and that most the steps you took were well-commented in your project.
# * It was very interesting to check your project and follow your thought!
#
# The work itself is at a good level! 😃
#
# </div>
#
#
#
# <s><font color='red'><b><u> Reviewer Comment V.1 </u></b></font>
#
# <div class="alert alert-danger">
#
# **General feedback**:
#
# **There are a couple of things that need to be done before your project is complete (I've left some comments below, [check the 1st](#issue1), [the 2nd](#issue2), [the 3d](#issue3)  and  [the 4th](#issue4))** .
#
# I appreciate the amount of work you've done! I am sure you can handle these issues below!
#
# Waiting for you fixes😉 </s>
#
#
#
#         Also I've left an "Remark & Recommendation" comment/s, which could help you to upgrade/boost/polish your project and further develop your skills. It doesn't mean that you've done something wrong, it just contains some advice on how it could be improved.
#
#
# </div>
#
#
# <div class="alert alert-block alert-warning">
#
# **For your future projects:**
#
#
#
# * Technical strings like `<matplotlib.axes._subplots.AxesSubplot at 0x7f69fa0023d0>` can be deleted with the use of `plt.show()` method (if it occurs). It will improve the visualization in the project.
#
# * It is worth for Data Analytics to describe the vizualization in detail. Great article with examples: [How to describe charts, graphs](https://preply.com/en/blog/charts-graphs-and-diagrams-in-the-presentation/#scroll-to-heading-6);
#
#
# * Also we could use `subplots` to plot several charts in one row, [this link can be helpfull](https://napsterinblue.github.io/notes/python/viz/subplots/).
#
# * Also it is good habbit to estimate  general statistics with the use of  [describe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html).
# </div>

# %% [markdown]
# # a successful game

# %% [markdown]
# i work for an online gaming company called Ice, they sell video games all over the world.
# my job is to fined patterns that will help the company identify games that will be successful.
# to help me reach my goal, the company has provided me with a table that contains a list of games, its genres and platforms, how many copies of each game where sold in different regions and, user and critic scores, and the games ESRB rating.

# %% [markdown]
# ## Outline of analysis

# %% [markdown]
# to successfully reach my goal, i most:
#
# 1. i need to inspect the data for any impurities  in the data.
#
# 1. i need to prepare the data for analysis. to do so, i need to:
#     1. see that every thing is written in an acceptable format.
#     1. deal with missing values.
#     1. convert data types to their correct type.
#     1. and create columns that will make analysis more convenient.
#
# 1. analyze the data i need to:
#     1. see what years are the most significant for me to reach a conclusion.
#     1. see which of the platforms has the highest popularity.
#     1. find if there is a correlation between user and critic score, to the games success.
#     1. find the most popular genres.
#     1. create a user profile for every region:
#         1. top platform for every region.
#         1. top genres in every region.
#         1. and dose ratings affect sales in different regions.
#
# 1. test hypothesis:
#     1. dose xbox1 have the same average ratting as pc.
#     1. dose the action genre have a larger average rating then sports games.

# %% [markdown]
#  <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** It is great that you started the project with an introduction and provide plan of further analysis steps 👍
#
# </div>

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd                                           
import numpy as np
from nltk.stem import SnowballStemmer
english_stemmer = SnowballStemmer('english')
import time
import datetime 
from datetime import datetime
import matplotlib.pyplot as plt
from math import factorial
from scipy import stats as st
from scipy.stats import norm
import seaborn as sns

# %%
try:
    games_df = pd.read_csv('games.csv')

except:
    games_df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
#  <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Great that imports and data load are grouped in different cells before at the beginning!
# </div>

# %% [markdown]
# # data inspection

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
games_df.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
games_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ## midway inspection conclusion

# %% [markdown]
# 1. i need to change all the columns names to lower case letters.
# 1. the year_of_release, the critic_score, user_score  and rating columns have missing values.
# 1. the user_score and year_of_release have incorrect value types.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Good that `info()` and `describe()` are used! The data was studied carefully, nice observations above
#
#
#
# </div>
#
# <font color='#ffa500'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-block alert-warning">
# <b>Recommendation</b>
#
# 1. The following piece of code can be usefull to estimate the percetage of values missing:
#
#     `df.isnull().sum()/ df.shape[0] * 100`
#
# 2. Also it is good habbit to estimate duplicates with the use of `duplicated()` method. Yes, there are no duplicated data, but it would be better not to forget about them:)
#
#
#
# </div>

# %% [markdown]
# # prepare the data

# %% [markdown]
# ## lower case columns

# %% [markdown]
# first i'm going to change all the columns names to lower case letters by using columns.str.lower().

# %%
games_df.columns = games_df.columns.str.lower()
games_df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Great that you have applied  `.lower()` to convert string data to the same lowercase format.
# </div>

# %% [markdown]
# ## dilling with missing values

# %% [markdown]
# i'm going to fill the missing values in the year column, by finding the mean of year for every platform, by using the groupby and transform method.
# i did that, because there are not many missing values in the year column, and u can pretty much determine the year of the game based on the platform. thats because allot of games are made for specific platforms, that where sold in a specific period of time.

# %%
games_df['year_of_release'] = games_df.groupby(['platform'])['year_of_release'].transform(lambda grp: grp.fillna(np.mean(grp)))
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <font color='orange'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-warning" >
#
# **Remark:** Okay, the `groupby` method was used here, but such method of filling can lead to the distortion of our results. We could just drop missing values in this column, because there are less than 2% missing values
# </div>

# %%
del_met = pd.isnull(games_df["name"])
games_df[del_met]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# for the missing values in the name column, i decided that they are not significant and so i can get rid of them.

# %%
games_df.drop(index= [659,14244],inplace=True)

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Correct, there are very few missing values
# </div>

# %% [markdown]
# in the rating column, i saw that there are a significant amount of missing values, almost half. so i can't see a safer thing then to fill in the values with the name column, using a similar thing way as before.
# before doing that, i will have to combine some values with the larger ones.
# i have to create a 2 libraries, one with the original values transformed to numbers, and one that dose the opposite thing.
# then i need to make a new column, apply what i did in the privies step, and use the second library to move the values to the rating columns. all the other nan values i'll declare as missing.

# %%
games_df["rating"].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64

# %%
games_df["rating"] = games_df["rating"].replace(["AO","RP"], "M")
games_df["rating"] = games_df["rating"].replace(["K-A","EC"], "E")
games_df["rating"].value_counts()
# Out:
# E       4001
# T       2961
# M       1567
# E10+    1420
# Name: rating, dtype: int64

# %%
rating_dict = {"E":0,"T":1,"M":2,"E10+":3}
el_riverso = {0:"E",1:"T",2:"M",3:"E10+"}
games_df["rating_dict"] = games_df["rating"].map(rating_dict)
games_df["rating_dict"].fillna(games_df.groupby(["name"])["rating_dict"].transform("median"),inplace = True)
games_df["rating_dict"].value_counts()
# Out:
# 0.0    4161
# 1.0    3090
# 2.0    1661
# 3.0    1468
# 1.5       4
# 0.5       2
# Name: rating_dict, dtype: int64

# %%
games_df["rating_dict"] = games_df["rating_dict"].replace([1.5,0.5], np.nan)
games_df["rating"] = games_df["rating_dict"].map(el_riverso)
del games_df["rating_dict"]
print(games_df.info())
games_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           10380 non-null  object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB
# None
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# ...

# %%
games_df["rating"].fillna("missing",inplace= True)
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           16713 non-null  object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** This step was done good, absolutely right decision was made about rating column! At the next steps we need to analyse the rating by the region, and it is better to take into account the games, where rating values are missed.

# %% [markdown]
# i didn't fill the missing values in the critic and user columns, because there are to much missing values for me to transform them using other columns, and that may create false data.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Good observations according to `critic score \ users score` columns, totaly agree with you!
#
# </div>

# %% [markdown]
# ## convert data types

# %% [markdown]
# to convert the type of the user score to flout, i need to replace all the nan's and tbd's with "11" strings. then it be converted to flout using astype(). after that i'll return all the 11 back to nun.

# %%
games_df["user_score"].fillna('11',inplace=True)
games_df["user_score"] = games_df["user_score"].replace(["tbd"], "11")
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       16713 non-null  object
#  10  rating           16713 non-null  object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Absolutely correct, we can assume that values `tdb` equal to nans in this case!
# </div>

# %%
games_df["user_score"] = games_df["user_score"].astype(float)
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       16713 non-null  float64
#  10  rating           16713 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.5+ MB

# %%
games_df["user_score"] = games_df["user_score"].replace([11], np.nan)
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# using astype() to convert the year column to int.

# %%
games_df["year_of_release"] = games_df["year_of_release"].astype(int)
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int32
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ## total sales

# %% [markdown]
# created the total_sales column by combining all sales from all regions so i can see an over all sales in the world.

# %%
games_df["total_sales"] = games_df["jp_sales"] + games_df["eu_sales"] + games_df["na_sales"] + games_df["other_sales"]
games_df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# ## midway conclusion

# %% [markdown]
# 1. i changed all column names to lower case.
# 1. filled the missing values in the year column.
# 1. deleted the rows that had missing values in the name column.
# 1. combined smaller values with larger ones in the rating column. and then filled some values.
# 1. converted the user score to flout.
# 1. converted the year column to int.
# 1. created a total_sales column that combines all the sales columns values.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v.1 </u></b></font>
# <div class="alert alert-success" >
#
# **Success:** Okay, this column was created correct! Also nice short conclusion above
# </div>
#
# <font color='orange'><b><u> Reviewer Comment. v.1 </u></b></font>
#
# <div class="alert alert-warning" >
#
# **Recommentation:**
#
# Btw you can also use the following code to calculate total sales:
#
#         games['total_sales']=games[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
#
# </div>

# %% [markdown]
# # analyze the data

# %% [markdown]
# ## year significance

# %% [markdown]
# by using box plot and a histogram, i'll see sales based on years. and i'll also see if there is to much of a skew in the data.

# %%
games_df["year_of_release"].value_counts()
# Out:
# 2008    1524
# 2009    1456
# 2010    1280
# 2007    1197
# 2011    1136
# 2006    1006
# 2005     939
# 2002     829
# 2003     821
# 2004     796
# 2012     653
# 2015     606
# 2014     582
# 2013     552
# 2016     502
# 2001     482
# 1998     389
# 2000     350
# 1999     338
# 1997     289
# 1996     263
# 1995     220
# 1994     121
# 1993      60
# 1982      53
# 1981      46
# 1992      43
# 1991      41
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# Name: year_of_release, dtype: int64

# %%
def boxplot_games(column):
    Q1 = games_df[column].quantile(0.25)
    Q3 = games_df[column].quantile(0.75)
    IQR = Q3 - Q1
    games_df.boxplot(column)
    plt.hlines(y = Q1-1.5*IQR, xmin = 0.9, xmax = 1.1, color = "red")
    plt.hlines(y = Q3 + 1.5*IQR, xmin = 0.9, xmax = 1.1, color = "red")

# %%
games_df.plot(y = "year_of_release", kind = "hist", bins = 37, xlim = (1975,2020), ylim = (0,1750))
plt.title('year_production')
plt.xlabel('year')
plt.ylabel('num_of_games')
plt.show()

# %%
plt.ylim(1970,2025)
boxplot_games("year_of_release")
plt.title('production_range')
plt.ylabel('year')
plt.show()

# %% [markdown]
# seems that the years with the most sales are around 2005- 2010. their weren't a lot of games before the 90's bot they are not harming the data.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Agree with your findings above, we can clearly see that on a chart above!  Also good that you use your own function and IQR method to investigate this question👌
# </div>

# %% [markdown]
# ## popularity of a platform

# %% [markdown]
# lets see what are the most popular platforms. i'll create a pivot table.

# %%
platform_sales = games_df.pivot_table(index = "platform", values = "total_sales",aggfunc= "sum")
platform_sales.sort_values(by="total_sales", ascending = False)
# Out:
#           total_sales
# platform
# PS2           1255.77
# X360           971.42
# PS3            939.65
# Wii            907.51
# DS             806.12
# PS             730.86
# GBA            317.85
# PS4            314.14
# PSP            294.05
# PC             259.52
# 3DS            259.00
# XB             257.74
# GB             255.46
# NES            251.05
# N64            218.68
# SNES           200.04
# GC             198.93
# XOne           159.32
# 2600            96.98
# WiiU            82.19
# PSV             54.07
# SAT             33.59
# GEN             28.35
# DC              15.95
# SCD              1.86
# NG               1.44
# WS               1.42
# TG16             0.16
# 3DO              0.10
# GG               0.04
# PCFX             0.03

# %% [markdown]
# seems that ps2 had the most sales so far. lets see how long it was on the market.

# %%
ps2_df = games_df.query('platform == "PS2"')
ps2_df.plot(y = "year_of_release", kind = "hist", bins = 12, xlim = (2000,2012), ylim = (0,400))
plt.title('ps2_popularity')
plt.xlabel('year')
plt.ylabel('num_of_games')
plt.show()

# %% [markdown]
# seems it made sales for 10 years. it had its peek around 2004-2005.

# %% [markdown]
# lets take some platforms with high sales, and see how long did they live in glory, and how long dose it take for a new platform to emerge. i'll fined that using the query method to chose some platforms, and then using some box plots to see their life span.

# %%
platform_lifetime_df = games_df.query('platform == ["PS2","PS3","X360","Wii","XB","GBA","DS","GB","NES","SNES"]')
platform_lifetime_df.boxplot(by='platform', column='year_of_release', figsize=(12,6), fontsize=14)
plt.title('platform_life_time')
plt.xlabel('platform')
plt.ylabel('year')
plt.show()

# %% [markdown]
# seems that a platforms life span varies, between 10-5 years. it depends on the size of the platforms.
# i'd say that on average, a new platform comes out every 5 years from each company, just a little after the peek of the privies model.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Yes, these platforms seem to be profitable. Nice and illustrative charts above, they can bring a lots of valuable insights!
# </div>

# %% [markdown]
# ## relevant years and platforms

# %% [markdown]
# i think, that based on the life time of a platform, the time it takes for its popularity to decline and the time it takes for a new platform to surface, the most relevant years for me are about 5-4 years back. i'll see how the last platforms did and draw my conclusions accordingly.
# i'll use the query method to get the relevant years, and then box plot to see the most successful platforms of the last 5 years.

# %% [markdown]
# <s><a id='issue1'></a>
# <font color='red'><b><u> Reviewer Comment. v.1 </u></b></font>
#
# <div class="alert alert-danger" >
#
# **Issue:**
#
#
# Pay attention, `relevant_years_df` dataframe is created below, but we see this variable in the cell above. It will lead to the mistake `NameError: name 'relevant_years_df' is not defined`.
#
#
# Please, correct this, we can swap these cells  or replace `relevant_years_df = games_df.query("year_of_release > 2005")` line to the cell above.
#
# </div>

# %%
relevant_years_df = games_df.query("year_of_release > 2012")
sns.boxplot(x="platform", y="total_sales", data= relevant_years_df, showfliers = False)
sns.set(rc={'figure.figsize':(15,8)})
plt.title('platform_sale')
plt.xlabel('platform')
plt.ylabel('sales_made')
plt.show()

# %%
platform_sales2 = relevant_years_df.pivot_table(index = "platform", values = "total_sales",aggfunc= "sum")
platform_sales2.sort_values(by = "total_sales", ascending = False)
# Out:
#           total_sales
# platform
# PS4            314.14
# PS3            181.43
# XOne           159.32
# 3DS            144.44
# X360           136.80
# WiiU            64.63
# PC              39.43
# PSV             33.25
# Wii             13.66
# PSP              3.50
# DS               1.54

# %% [markdown]
# it seems that the platforms with the highest sales are ps4 ps3, xone, 3ds and x360 . bot some of them reached their peek, xone is going to gain even more popularity and x360 is not going to be relavent. same with ps4 and ps3, ps3 has reached its potential and ps 4 has still a place to grow. it seems that the ones who are groing now are ps4,xone,the 3ds, wiiu and psv.

# %% [markdown]
# <a id='issue2'></a>
# <s><font color='red'><b><u> Reviewer Comment. v.1 </u></b></font>
#
# <div class="alert alert-danger" >
#
# **Issue:**
#
#
# As I have understand correctly, the lower border of actual (current) period is 2006. But it is not a very correct lower border for the actual period, let's see
#
# The relevance of the game falls according to the plots on average for 3-5 years (if you build barplots for each platform sales per year you will see it) since games quickly become obsolete. Accordingly, if we choose a longer period, for example, as in your case, we risk capturing a lagging trend, i.e. we include in the data irrelevant pre-period platforms that should not remain in the data for the predicted period.
#
#
# * For example, the case of PS2. We see that the leader in sales in the entire history of the PS, but sales by 2011 are already zero. That is why the choice of 2006 year as a start year can catch the outdated tendency and bias the results of your analysis at the next steps.
#
#
#
# **It is better to use 2013-2014 year as the lower border of the currect period.** The year that can be considered as boundary of the current period, can be determined by building histograms for each platform. The histograms will show that games lose relevance within 3-4, maximum 5 years. The final year of the dataset is 2016, so we subtract 3-4 years from 2017 (as the year for which we buid the prediction) and get a year, which can be considered the boundary of the current period.
#
#
#
#     Please, use data from 2013 or 2014. It would be more informative for our forecast.
#
# **I will check next steps with new actual period, but also I've left some comments below.**
#
# </div>

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 2 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Great, thank you for correcting the issue above!
# </div>

# %% [markdown]
# ## critic vs user on platform success

# %% [markdown]
# now, using scatter plots and the corr method, i'm going to check if the scores given by critics and users determine the success of a platform.

# %%
x360_df = relevant_years_df.query('platform == "PS4"')
x360_df.plot.scatter(y="total_sales",x="critic_score")
plt.title('critic_for_sales')
plt.xlabel('critic_score')
plt.ylabel('sales')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
#
# <s><font color='orange'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-warning" >
#
# Technical strings like `Text(0, 0.5, 'sales')` can be deleted with the use of `plt.show()` method (if it occurs) or ; sign.
# It will improve the visualization in the project:)
#
# </div>

# %%
x360_df = relevant_years_df.query('platform == "PS4"')
x360_df.plot.scatter(y="total_sales",x="user_score")
plt.title('user_for_sales')
plt.xlabel('user_score')
plt.ylabel('sales')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
corr = sns.heatmap(x360_df.corr(), annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm')
corr
plt.show()

# %% [markdown]
# it seems that critics have much more affect on sales then users.

# %% [markdown]
# ## most popular genres

# %% [markdown]
# lets see how genres affect sales. to do so, ill create a pivot table and a box plot.

# %%
genres_df = relevant_years_df.pivot_table(index= "genre",values = "total_sales", aggfunc= "sum")
genres_df.sort_values(by="total_sales",ascending= False)
# Out:
#               total_sales
# genre
# Action             322.27
# Shooter            233.05
# Sports             150.67
# Role-Playing       146.18
# Misc                62.82
# Platform            42.63
# Racing              39.98
# Fighting            35.31
# Adventure           23.73
# Simulation          22.25
# Strategy            10.08
# Puzzle               3.17

# %% [markdown]
# <s><a id='issue3'></a>
# <font color='red'><b><u> Reviewer Comment. v.1 </u></b></font>
#
# <div class="alert alert-danger" >
#
# **Issue:**
#
# The code above doesn't run, please, fix it  :)
# </div>

# %%
sns.boxplot(x="genre", y="total_sales", data= relevant_years_df, showfliers = False)
sns.set(rc={'figure.figsize':(15,8)})
plt.title('genre_sales')
plt.xlabel('genre')
plt.ylabel('sales_made')
plt.show()

# %% [markdown]
# when we look at the pivot table it seems that the action genre is the most popular. but when we look at the box plot, on average the shooter games are making a lot more sales per game, witch means that the action games are making more sales because there are just more of them. it will be wise to put on emphasis on shooter, sports and platform games.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v.1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Good that `median` was used here, it's more correct to pay attention on this metric (or mean values) at this step!
# </div>

# %% [markdown]
# ## user profile

# %% [markdown]
# ### top platform in every region

# %% [markdown]
# lets see the top platform in every region. to do so, i'll create a pivot table for platforms in every region and a pie plot, to see them in percentage.

# %%
top_platform_jp = relevant_years_df.pivot_table(values = "jp_sales", index = "platform", aggfunc = "sum")

(top_platform_jp
    
    .sort_values(by = "jp_sales" ,ascending = False)
    .plot(y = "jp_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("platform_sales_in_jp")
plt.ylabel('sales')
top_platform_jp
# Out:
#           jp_sales
# platform
# 3DS          67.86
# DS            0.00
# PC            0.00
# PS3          23.35
# PS4          15.96
# PSP           3.29
# PSV          18.66
# Wii           0.05
# WiiU         10.88
# X360          0.51
# XOne          0.34

# %% [markdown]
# seems that japan likes their own things the most. when we look at the top 5, 3ds,psv,ps4 and wiiu are going to continue to grow in jp, but it's soon going to be the end of ps3. bot continue the sales of 3ds as much as possible, it's really going strong.

# %%
top_platform_na = relevant_years_df.pivot_table(values = "na_sales", index = "platform", aggfunc = "sum")

(top_platform_na
    
    .sort_values(by = "na_sales" ,ascending = False)
    .plot(y = "na_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("platform_sales_in_na")
plt.ylabel('sales')
top_platform_na
# Out:
#           na_sales
# platform
# 3DS          39.04
# DS            0.57
# PC           11.11
# PS3          63.50
# PS4         108.74
# PSP           0.00
# PSV           5.15
# Wii           6.56
# WiiU         29.21
# X360         81.66
# XOne         93.12

# %% [markdown]
# the biggest difference with jp and na is the popularity of ps4 in contrast to 3ds. seems that there are two old platforms at the top there, the x360 and ps3. so i'd say that in na we should focus on ps4 xone and 3ds. they, an like the jp, prefer the bigger platforms.

# %%
top_platform_eu = relevant_years_df.pivot_table(values = "eu_sales", index = "platform", aggfunc = "sum")

(top_platform_eu
    
    .sort_values(by = "eu_sales" ,ascending = False)
    .plot(y = "eu_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("platform_sales_in_eu")
plt.ylabel('sales')
top_platform_eu
# Out:
#           eu_sales
# platform
# 3DS          31.17
# DS            0.85
# PC           25.36
# PS3          67.81
# PS4         141.09
# PSP           0.17
# PSV           6.15
# Wii           5.93
# WiiU         19.85
# X360         42.52
# XOne         51.59

# %% [markdown]
# seems like the eu is much more similar to na then jp, they dont like the ds3 as much and they prefer ps4 much more. but they like the ps platform, even ps4 is quite popular. wiiu not doing so hot in any of the regions.

# %% [markdown]
# ### top genres

# %% [markdown]
# lets see popular genres in different regions, using the same methods as before.

# %%
top_genre_eu = relevant_years_df.pivot_table(values = "eu_sales", index = "genre", aggfunc = "sum")

(top_genre_eu
    
    .sort_values(by = "eu_sales" ,ascending = False)
    .plot(y = "eu_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("genre_sales_in_eu")
plt.ylabel('sales')
top_genre_eu
# Out:
#               eu_sales
# genre
# Action          118.32
# Adventure         8.25
# Fighting          8.55
# Misc             20.04
# Platform         15.58
# Puzzle            1.00
# Racing           20.19
# Role-Playing     37.02
# Shooter          87.88
# Simulation       10.92
# Sports           60.52
# Strategy          4.22

# %% [markdown]
# seems like in the eu we can see that the most soled games are action, again because of the amount, then we have the shooter, sports, rp and racing.

# %%
top_genre_jp = relevant_years_df.pivot_table(values = "jp_sales", index = "genre", aggfunc = "sum")

(top_genre_jp
    
    .sort_values(by = "jp_sales" ,ascending = False)
    .plot(y = "jp_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("genre_sales_in_jp")
plt.ylabel('sales')
top_genre_jp
# Out:
#               jp_sales
# genre
# Action           40.49
# Adventure         5.82
# Fighting          7.65
# Misc              9.20
# Platform          4.79
# Puzzle            1.18
# Racing            2.30
# Role-Playing     51.14
# Shooter           6.61
# Simulation        4.52
# Sports            5.43
# Strategy          1.77

# %% [markdown]
# in jp, we have a lot of sales for rp, very different from eu, then actions. this two take 2/3 of the hole sales alone. then misc, fighting and shooter.

# %%
top_genre_na = relevant_years_df.pivot_table(values = "na_sales", index = "genre", aggfunc = "sum")

(top_genre_na
    
    .sort_values(by = "na_sales" ,ascending = False)
    .plot(y = "na_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("genre_sales_in_na")
plt.ylabel('sales')
top_genre_na
# Out:
#               na_sales
# genre
# Action          126.23
# Adventure         7.22
# Fighting         15.55
# Misc             27.49
# Platform         18.14
# Puzzle            0.83
# Racing           13.04
# Role-Playing     46.51
# Shooter         109.78
# Simulation        5.32
# Sports           65.27
# Strategy          3.28

# %% [markdown]
# seems that the eu and na are similar, having action games on top, on like jp how prefers rp games and greatly dislikes shooter games. other then that there similar.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
#
# <div class="alert alert-success">
#
# **Recommendation:** Nice pie charts above!
#
# Also it is possible to use subplots to create one graph with 3 columns per market:
#         fig, axs = plt.subplots(1, 3, figsize=(15, 5))
#
# [This link can be helpfull](https://napsterinblue.github.io/notes/python/viz/subplots/).
#
# </div>

# %% [markdown]
# ### ESRB affect

# %% [markdown]
# lets see if there are any differences when it comes to rating, and how it affects sales in every region. i'll do it using scatter plots.

# %%
top_esrb_na = relevant_years_df.pivot_table(values = "na_sales", index = "rating", aggfunc = "sum")

(top_esrb_na
    
    .sort_values(by = "na_sales" ,ascending = False)
    .plot(y = "na_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("rating_sales_in_na")
plt.ylabel('sales')
top_esrb_na
# Out:
#          na_sales
# rating
# E           82.06
# E10+        56.64
# M          175.10
# T           52.27
# missing     72.59

# %% [markdown]
# seems that in na, people prefer the m games, and t games the least.

# %% [markdown]
# <s><a id='issue4'></a>
# <font color='red'><b><u> Reviewer Comment. v.1 </u></b></font>
#
# <div class="alert alert-danger" >
#
# **Issue:**
#
# The code above doesn't run, please, fix it  too. Also I'd advise to use barcharts\piecharts to depict these top-5, it could be informative and readable
# </div></s>
#
# <font color='green'><b><u> Reviewer Comment. v. 2 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** Thank you for correcting this issue! Looks better👌
# </div>

# %%
top_esrb_jp = relevant_years_df.pivot_table(values = "jp_sales", index = "rating", aggfunc = "sum")

(top_esrb_jp
    
    .sort_values(by = "jp_sales" ,ascending = False)
    .plot(y = "jp_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("rating_sales_in_jp")
plt.ylabel('sales')
top_esrb_jp
# Out:
#          jp_sales
# rating
# E           16.00
# E10+         6.27
# M           14.87
# T           22.91
# missing     80.85

# %% [markdown]
# seems that in jp most of the sales rating are missing. but it dose seem that t games are the most popular.

# %%
top_esrb_eu = relevant_years_df.pivot_table(values = "eu_sales", index = "rating", aggfunc = "sum")

(top_esrb_eu
    
    .sort_values(by = "eu_sales" ,ascending = False)
    .plot(y = "eu_sales",kind = "pie", figsize = (15,15), autopct = '%1.0f%%')
    
)
plt.title("rating_sales_in_eu")
plt.ylabel('sales')
top_esrb_eu
# Out:
#          eu_sales
# rating
# E           85.46
# E10+        45.39
# M          156.67
# T           43.73
# missing     61.24

# %% [markdown]
# and eu is just like the na.

# %% [markdown]
# ## midway analysis conclusion

# %% [markdown]
# 1. using histograms and box plots i analyzed the most relevant years of analysis and the most relevant platforms.
# 1. looking at the scatter plots i made i got the filing that user score don't have much of an impact on sales like critics do.
# 1. looking at the pivot table and box plot, i saw that the platform, shooting and sports are quite popular, an like puzzles and adventure.
# 1. using pie plots, i sew that when it comes to taste the na and eu are very similar in taste. they all like ps4 and xone the most, and rely loved shooter games, and prefer the m games. an like jp, how preferred the ds3 the most, which got a low grade in the na and eu alike, and loves rp games the most, and prefer the t games.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v.2 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success:** I couldn't agree more with the findings above! We can see that Japan is different, perhaps because of culture and traditions🙂
#
# Thank you for the corrections above, now this step's done right!
#
# </div>

# %% [markdown]
# # test hypotheses

# %% [markdown]
# now using hypotheses on equality of two population means, im going to check tow hypothesis.
# 1. h1: the average user score of xone is equal to pc.
# 1. h2: the average user score of action is different from sports.
#
# lets start with h1.

# %% [markdown]
# ## xbox vs pc

# %%
xbox1_df=relevant_years_df[(relevant_years_df['platform']=='XOne')& (relevant_years_df['user_score'].notnull())]
pc_df=relevant_years_df[(relevant_years_df['platform']=='PC')& (relevant_years_df['user_score'].notnull())]
print(np.var(xbox1_df["user_score"]))
np.var(pc_df["user_score"])
# Out:
# 1.8965188383045533
# 3.0163063475546332

# %%
print(xbox1_df["user_score"].mean())
pc_df["user_score"].mean()
# Out:
# 6.52142857142857
# 6.269677419354836

# %%
alpha = 0.05

results = st.ttest_ind(xbox1_df["user_score"], pc_df["user_score"],equal_var=False)

print('p-value: ', results.pvalue)

if results.pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value:  0.14759594013430463
# We can't reject the null hypothesis

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>
#
# whay am i getting nan's?
# </div>

# %% [markdown]
# i see that the hypotheses is right, which is strange because xone has more sales then pc.

# %% [markdown]
# <a id='issue5'></a>
# <font color='red'><b><u> Reviewer Comment. v.2 </u></b></font>
#
# <div class="alert alert-danger" >
#
# **Issue:**
#
# Pay attention, it's needed to delete nans in the data before testing. We can delete or filter null values, for example:
# `sp_df=df[(df['genre']=='Sports')& (df['user_score'].notnull())]`
#
#
# Please, correct this step a little bit.

# %% [markdown]
# ## action vs sports

# %% [markdown]
# now moving to h2 hypotheses.

# %%
action_df=relevant_years_df[(relevant_years_df['genre']=='Action')& (relevant_years_df['user_score'].notnull())]
sports_df=relevant_years_df[(relevant_years_df['genre']=='Sports')& (relevant_years_df['user_score'].notnull())]
print(np.var(action_df["user_score"]))
np.var(sports_df["user_score"])
# Out:
# 1.7605786324786343
# 3.1607339843749975

# %%
print(action_df["user_score"].mean())
sports_df["user_score"].mean()
# Out:
# 6.836666666666672
# 5.238124999999999

# %%
alpha = 0.05

results = st.ttest_ind(action_df["user_score"], sports_df["user_score"],equal_var=False)

print('p-value: ', results.pvalue)

if results.pvalue < alpha:
    print("We can't reject the null hypothesis")
else:
    print("We reject the null hypothesis")
# Out:
# p-value:  1.4711831608728666e-20
# We can't reject the null hypothesis

# %% [markdown]
# that means that on average the action games are gating better scores then the sports games, which is odd, because on average sports games are selling better.

# %% [markdown]
# # summary

# %% [markdown]
# 1. in the data preparation stage:
#     1. i changed the columns names to lower case letters using columns.str.lower().
#     1. i deleted rows with missing values in the name column.
#     1. i filled the year column using the transform and group by methods.
#        using the mean of the column according to the platform.
#     1. i filled some missing values in the rating column,
#        using 2 libraries to turn the column to numeric,
#        and then return it after getting the values from the transform and group by methods.
#     1. i grouped the smaller values in the rating columns with the big ones.
#     1. i didn't try filling the values of the user and critic columns,
#        because they had to many missing values and i did not want to create half the data in the columns.
#     1. i converted the data type of years to int, and the user to flout.
#        i did that by turning all nan's and tbd's to 11, and then converting the column using astype.
#        after that i turned all the 11's to nan's  using replace.
#     1. by combining all the sales columns i crated the total sales column.
# 1. in the analysis stage:
#     1. using histograms and box plots, i found the most relevant years for analysis,
#        and the most popular platforms. the life span of a platform, and when to expect a new one.
#     1. using scatter plots i checked if user and critic scores have any impact on sales.
#     1. using pivot tables and box plots i checked what are the most popular genres.
#     1. using pie plots i checked if there is a difference from region to region in preferred genres, platforms, and rankings.
# 1. in the hypothesis state:
#     1. i checked two hypothesis: h1 is that the average user score of xone is the same as pc.
#        h2 was that the average user score of sports is different from action.
#     1. i used the hypotheses on equality of two population means to get an answer to both.

# %% [markdown]
# ## conclusion

# %% [markdown]
# 1. the most relevant years are from 2013 to 2016, thats because the most platforms have raising sales for around 5 years.
#    that means that we need to look at the most successful platforms in this period.
# 1. i found that the most popular platforms are the xone, wiiu, ps3,3ds,ps4.
#    but the ones that are growing right now are ps4,xone,3ds  wiiu.
# 1. critic score has much more of an impact on the sales of the games then users,
#    so it's smart to stay tuned to what they have to say.
# 1. the genres with the most sales on average are shooting, sports and platform.
#    the company needs to keep an eye out for platform games, there aren't a lot of them, bot they hit big.
# 1. the na and eu are much more aligned with what they want.
#    they will prefer the ps4, the xone, the wiiu and the 3ds in that order in the future.
# 1. when it comes to games, the na and eu love action, sports, shooting and rp in that order.
# 1. and in rating, the m games are the most desirable.
# 1. jp has it's own things. when it comes to platforms they like the small ones and they don't xbox.
#    jp will like the 3ds, psv, ps4 and wiiu in that order in the future.
# 1. when it comes to genre, jp likes rp more then any thing, then action, misc, fighting, and shooter, in that order.
# 1. when it comes to rating, they prefer the t games. it is very important to make those differences between jp and the others.

# %% [markdown]
# <font color='green'><b><u> Reviewer Comment. v. 1 </u></b></font>
#
# <div class="alert alert-success" >
#
# **Success**:
#
# The overall conclusion is clear and logical, most importantly, it is supported by the revealed facts!
#
# </div>
